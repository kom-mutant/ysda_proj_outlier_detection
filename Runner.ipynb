# %%
# %pip install -r requirements.txt

# %%
# %run benchmark/run_benchmark.py   --datasets Yahoo  --models benchmark/models.json5  --logger inline   --output_csv two_algos_1_results.csv  --time_series_metrics_csv two_algos_first_metrics.csv
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'Could not load this library: /usr/local/lib/python3.10/dist-packages/torchvision/image.so'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 2026-01-21 18:08:38.419427: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %pip install tsfm_public[notebooks] git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.18
# Out:
# Unknown instance spec: Please select VM configuration

# %%
from tsfm_public.models.tspulse.modeling_tspulse import TSPulseForReconstruction
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'Could not load this library: /usr/local/lib/python3.10/dist-packages/torchvision/image.so'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 2026-01-20 20:19:44.690956: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
import tsfm_public
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4764/3033065769.py in <cell line: 1>()
# ----> 1 import tsfm_public
#
# ~/.local/lib/python3.10/site-packages/tsfm_public/__init__.py in <module>
#      10 from transformers.utils import _LazyModule
#      11
# ---> 12 from tsfm_public.toolkit.hf_util import register_config
#      13
#      14 from .version import __version__, __version_tuple__
#
# ModuleNotFoundError: No module named 'tsfm_public.toolkit'

# %%
print(tsfm_public.__version__)
# Out:
# Processing time series with Autoregressive: 0it [08:40, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7097/2394248740.py in <cell line: 1>()
# ----> 1 print(tsfm_public.__version__)
#
# NameError: name 'tsfm_public' is not defined

# %%
attributes = dir(tsfm_public)

for attr in attributes:
    print(attr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4764/2227499353.py in <cell line: 1>()
# ----> 1 attributes = dir(tsfm_public)
#       2
#       3 for attr in attributes:
#       4     print(attr)
#
# NameError: name 'tsfm_public' is not defined

# %%
# %pip freeze
# Out:
# absl-py==2.3.1
# accelerate==1.12.0
# aiobotocore==2.1.2
# aiohappyeyeballs==2.6.1
# aiohttp==3.13.3
# aiohttp-retry==2.8.3
# aioitertools==0.11.0
# aiosignal==1.4.0
# alabaster==0.7.13
# albumentations==1.2.1
# alembic==1.18.1
# altair==4.2.2
# amqp==5.1.1
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.12.1
# appdirs==1.4.4
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# array-record==0.4.0
# arrow==1.4.0
# arviz==0.15.1
# astropy==5.2.2
# asttokens==3.0.0
# astunparse==1.6.3
# async-lru==2.1.0
# async-timeout==4.0.2
# asyncssh==2.13.2
# atpublic==4.0
# attrs==25.4.0
# audioread==3.0.0
# autograd==1.6.2
# babel==2.17.0
# backcall==0.2.0
# bcrypt==4.0.1
# beautifulsoup4==4.14.3
# billiard==4.1.0
# bleach==6.3.0
# blinker==1.4
# blis==0.7.10
# blosc2==2.0.0
# bokeh==3.1.1
# boto3==1.20.24
# botocore==1.23.24
# branca==0.8.2
# build==0.10.0
# CacheControl==0.13.1
# cachetools==5.3.1
# catalogue==2.0.9
# category_encoders==2.8.1
# celery==5.3.1
# ...
